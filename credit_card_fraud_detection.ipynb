# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score

# %%
 # or readline if the file is large
df = pd.read_csv('/content/spam.csv', encoding=result['encoding'])

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2

# %%
df.isnull().sum()
# Out:
# v1               0
# v2               0
# Unnamed: 2    5522
# Unnamed: 3    5560
# Unnamed: 4    5566
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 403

# %%
df = df.drop_duplicates( keep='first')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5169 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5169 non-null   object
#  1   v2          5169 non-null   object
#  2   Unnamed: 2  43 non-null     object
#  3   Unnamed: 3  10 non-null     object
#  4   Unnamed: 4  5 non-null      object
# dtypes: object(5)
# memory usage: 242.3+ KB

# %%
# Create a sample DataFrame
df = pd.DataFrame({
    'Class': ['legit', 'legit', 'fraudulent', 'legit', 'fraudulent', 'legit']
})

# Find the distribution of the 'Class' column
distribution = df['Class'].value_counts()

# Print the distribution
print(distribution)
# Out:
# Class
# legit         4
# fraudulent    2
# Name: count, dtype: int64

# %%
#this data set is higly unbalanced
#0 represents legit trans
#1 represents fraud trans

# %%
legit =df[df.Class == 0]
fraud =df[df.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (0, 1)
# (0, 1)

# %%
# Create a sample DataFrame
legit = pd.DataFrame({
    'Amount': [100, 200, 300, 400, 500]
})

# Find the summary statistics of the 'Amount' column
summary = legit['Amount'].describe()

# Print the summary
print(summary)
# Out:
# count      5.000000
# mean     300.000000
# std      158.113883
# min      100.000000
# 25%      200.000000
# 50%      300.000000
# 75%      400.000000
# max      500.000000
# Name: Amount, dtype: float64

# %%
print(summary)
# Out:
# count      5.000000
# mean     300.000000
# std      158.113883
# min      100.000000
# 25%      200.000000
# 50%      300.000000
# 75%      400.000000
# max      500.000000
# Name: Amount, dtype: float64

# %%
#Compares the values for both trans
df.groupby('Class').mean()
# Out:
# Empty DataFrame
# Columns: []
# Index: [fraudulent, legit]

# %%
#under sampling

# %%
# Create a sample dataset for legit_sample
legit_sample = pd.DataFrame({'feature1': [1, 2, 3], 'feature2': [4, 5, 6]})

# Assume fraud is already defined
fraud = pd.DataFrame({'feature1': [7, 8, 9], 'feature2': [10, 11, 12]})

# Concatenate legit_sample and fraud
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.describe()
# Out:
#        feature1   feature2
# count  6.000000   6.000000
# mean   5.000000   8.000000
# std    3.405877   3.405877
# min    1.000000   4.000000
# 25%    2.250000   5.250000
# 50%    5.000000   8.000000
# 75%    7.750000  10.750000
# max    9.000000  12.000000

# %%
new_dataset.head()
# Out:
#    feature1  feature2
# 0         1         4
# 1         2         5
# 2         3         6
# 0         7        10
# 1         8        11

# %%
print(new_dataset.columns)
# Out:
# Index(['feature1', 'feature2'], dtype='object')

# %%
X1 = new_dataset.drop(columns='Class', axis=1, errors='ignore')

# %%
print(X1)
# Out:
#    feature1  feature2
# 0         1         4
# 1         2         5
# 2         3         6
# 0         7        10
# 1         8        11
# 2         9        12

# %%
Y1 = new_dataset.drop(columns='Class', axis=1, errors='ignore')

# %%
print(Y1)
# Out:
#    feature1  feature2
# 0         1         4
# 1         2         5
# 2         3         6
# 0         7        10
# 1         8        11
# 2         9        12

# %%
X1_train,X1_test,Y1_train,Y1_test=train_test_split(X1,Y1,test_size=0.3,random_state=123)

# %%
print(X1.shape,X1_train.shape , X1_test.shape)
# Out:
# (6, 2) (4, 2) (2, 2)

# %%
lr=LogisticRegression()

# %%
# MODEL 2

# %%
from sklearn.model_selection import train_test_split

# %%
X2 = new_dataset.drop(columns='Class', axis=1, errors='ignore')

# %%
print(new_dataset.columns)
# Out:
# Index(['feature1', 'feature2'], dtype='object')

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()
